# %%
import pandas as pd

# %%
df_phishing = pd.read_csv(r'C:\Users\user\Desktop\woogawooga\woogawooga_project\dataset\phishing_2차모델용.csv')
df_normal = pd.read_csv(r'C:\Users\user\Desktop\woogawooga\woogawooga_project\dataset\normal_2차모델용.csv')
